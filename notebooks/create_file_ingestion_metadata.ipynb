# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.metadata;

CREATE TABLE IF NOT EXISTS workspace.metadata.file_ingestion_audit (
    file_path STRING,
    ingestion_time TIMESTAMP,
    status STRING
)
USING DELTA;
